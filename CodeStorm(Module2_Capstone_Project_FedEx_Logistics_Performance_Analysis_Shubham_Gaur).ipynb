# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhamgaur12/Module2_Capstone_Project_FedEx_Logistics_Performance_Analysis_Shubham_Gaur/blob/main/CodeStorm(Module2_Capstone_Project_FedEx_Logistics_Performance_Analysis_Shubham_Gaur).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - FedEx Logistics Performance Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1** - Shubham Gaur

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Enhancing FedEx Logistics Performance Through Data Analysis**
#
# In today’s highly interconnected global economy, logistics plays a critical role in ensuring the smooth movement of goods across international markets. Companies that operate on a global scale rely heavily on efficient supply chain networks to maintain service reliability and meet increasing customer expectations. Among the leading organizations in this domain, FedEx Logistics serves as a key facilitator of global trade by providing transportation, distribution, and supply chain management solutions across multiple industries and regions. With the rapid expansion of eCommerce and the growing complexity of international distribution networks, logistics efficiency has become more important than ever for maintaining operational excellence and a competitive advantage.
#
# The rise of online retail has significantly increased the volume and frequency of shipments worldwide. Customers now expect faster delivery times, greater transparency in shipment tracking, and reliable service regardless of geographic location. To meet these expectations, logistics companies must continuously optimize their operations, improve delivery performance, and manage costs effectively. Any inefficiencies in transportation routes, shipping methods, vendor management, or cost allocation can lead to delays, higher operational expenses, and reduced customer satisfaction. Therefore, analyzing logistics performance data is essential for identifying operational bottlenecks and uncovering opportunities for improvement.
#
# This project focuses on leveraging FedEx Logistics data to generate meaningful insights that can enhance supply chain efficiency and overall logistics performance. By analyzing shipment patterns, freight costs, delivery timelines, and vendor performance, the study aims to identify key factors that influence operational effectiveness. The primary goal is to support data-driven decision-making that can help streamline logistics processes, reduce unnecessary expenses, and improve service reliability. Through a structured analysis of logistics operations, the project seeks to provide actionable recommendations that can strengthen FedEx’s position in the competitive global logistics market.
#
# The dataset used for this analysis provides a comprehensive view of logistics activities and operational performance. It includes detailed information about shipment modes, origin and destination countries, vendor participation, line item values, package weights, freight costs, and delivery delay records. These variables collectively offer valuable insights into how shipments are managed and how different factors impact logistics efficiency. For example, shipment modes help identify the most commonly used transportation methods and their associated performance levels. Similarly, vendor data allows for the evaluation of third-party logistics providers and their contribution to delivery outcomes.
#
# In addition, freight cost and package weight data enable an assessment of cost structures and pricing efficiency within the logistics network. Understanding how these factors interact can reveal areas where cost optimization is possible without compromising service quality. Geographic data related to origin and destination countries further supports the identification of regional trends, such as high-cost routes or locations prone to delivery delays. By examining these patterns, organizations can better allocate resources, optimize routes, and improve overall supply chain planning.
#
# Another important aspect of the dataset is the inclusion of delivery delay records, which provide insights into the reliability of shipment operations. Delays can occur due to various reasons, including inefficient routing, vendor-related issues, or external factors such as customs processing and transportation disruptions. Analyzing these delays helps identify recurring challenges and potential areas for operational improvement.
#
# Overall, this project aims to transform raw logistics data into actionable insights that can drive operational efficiency and strategic decision-making. By leveraging data analytics techniques, the analysis seeks to uncover hidden patterns, evaluate performance across multiple dimensions, and recommend practical improvements. Ultimately, these insights can help FedEx Logistics enhance delivery efficiency, reduce costs, improve vendor management, and provide a better customer experience in an increasingly competitive and fast-paced global logistics environment.
#
# fedx logistic data set project summary in 500 -550 words
# FedEx Logistics Dataset Project Summary
#
# In the modern global economy, efficient logistics and supply chain management are essential for organizations that operate across international markets. As global trade and eCommerce continue to expand, logistics companies must manage increasing shipment volumes while ensuring reliability, cost efficiency, and customer satisfaction. FedEx Logistics is one of the key players in this industry, providing comprehensive transportation, distribution, and supply chain services to businesses worldwide. This project focuses on analyzing the FedEx Logistics dataset to understand operational patterns, identify inefficiencies, and provide data-driven insights that can improve logistics performance.
#
# The primary objective of this project is to evaluate shipment operations and uncover opportunities to enhance delivery efficiency, reduce operational costs, and improve customer service. By examining logistics data, the analysis aims to highlight key factors that affect shipment performance, including transportation modes, vendor participation, freight costs, and delivery timelines. Understanding these factors can help organizations optimize supply chain processes and make informed strategic decisions.
#
# The dataset used in this project provides detailed information related to logistics operations. It includes variables such as shipment modes, origin and destination countries, vendor involvement, line item values, package weights, freight costs, and delivery delay records. These data elements offer a comprehensive overview of shipment activities and allow for both macro-level trend analysis and detailed operational evaluation. By analyzing these variables, the project identifies patterns that influence delivery performance and cost efficiency.
#
# One of the key areas explored in this project is the relationship between shipment methods and delivery efficiency. Different shipping modes have varying costs, transit times, and reliability levels. By studying these patterns, the analysis helps determine whether certain shipping methods are overused or underutilized and whether they contribute to delays or increased expenses. This insight can support better decision-making when selecting transportation methods for future shipments.
#
# Another important focus of the project is freight cost analysis. Freight expenses represent a significant portion of logistics operations, and inefficient cost management can reduce profitability. The dataset allows for the examination of freight cost variations across vendors, shipment weights, and geographic regions. Identifying areas with unusually high shipping costs can help logistics managers investigate the underlying causes and develop strategies to optimize transportation expenses.
#
# Vendor performance evaluation is also a crucial aspect of the analysis. Logistics operations often rely on third-party vendors for transportation and distribution services. However, vendor performance may vary based on reliability, cost efficiency, and delivery timeliness. By analyzing vendor-related data, the project highlights performance differences and identifies vendors that consistently meet service expectations. This information can support more effective vendor management and partnership strategies.
#
# Additionally, the project examines delivery delays to identify operational bottlenecks within the logistics network. Delays can negatively impact customer satisfaction and disrupt supply chain operations. By analyzing delay patterns across different routes, vendors, and shipment methods, the project helps identify common sources of inefficiency. Addressing these issues can significantly improve service reliability and delivery performance.
#
# Overall, the FedEx Logistics dataset project demonstrates the importance of data analytics in improving supply chain operations. By transforming raw logistics data into meaningful insights, the analysis provides valuable recommendations for optimizing shipping methods, controlling freight costs, and improving vendor performance. These insights can help FedEx enhance operational efficiency, reduce delivery delays, and maintain a strong competitive position in the global logistics industry.

# %% [markdown]
# ## **Details**
# Efficient logistics operations are critical for global delivery companies.
# This project analyzes shipment data to understand patterns in delivery performance,
# freight cost, shipment modes, and delivery delays.
# ![image.png](data:image/png;base64,...)
# ### **Goals**
# - Understand shipment distribution across countries
# - Analyze freight cost patterns
# - Evaluate delivery delays
# - Study shipment modes used by FedEx
# - Identify factors affecting logistics performance

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Shubhamgaur12/Module2_Capstone_Project_FedEx_Logistics_Performance_Analysis_Shubham_Gaur

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# - High dependency on a single shipping method, reducing flexibility and increasing risk during disruptions.
#
# - Inconsistent relationship between shipping cost and service quality, where higher costs do not always result in better delivery performance.
#
# - Frequent and costly delivery delays, affecting operational efficiency and customer satisfaction.
#
# - Inefficient cost structure in logistics operations, leading to higher transportation and operational expenses.
#
# - Geographic concentration of high-cost shipments, indicating regional inefficiencies in the supply chain network.
#
# - Unpredictable and volatile freight costs, making budgeting and cost forecasting difficult.
#
# - Suboptimal vendor strategy and performance management, with inconsistent performance across logistics vendors.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# - Optimize FedEx Logistics' global supply chain operations using data-driven insights.
#
# - Improve delivery efficiency by analyzing shipping methods and logistics performance.
#
# - Enhance customer satisfaction through faster and more reliable deliveries.
#
# - Identify bottlenecks in the logistics network causing delays and inefficiencies.
#
# - Streamline logistics processes to reduce operational costs.
#
# - Ensure timely deliveries across regions to strengthen service reliability.
#
# - Support FedEx in maintaining a competitive advantage in the global eCommerce and logistics market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %%
# Import NumPy library
# Used for numerical operations, arrays, and mathematical functions
import numpy as np

# Import Pandas library
# Used for data manipulation and analysis using DataFrames and Series
import pandas as pd

# Import Matplotlib's pyplot module
# Used for creating basic plots and visualizations
import matplotlib.pyplot as plt

# Import Seaborn library
# Built on top of matplotlib and used for advanced statistical visualizations
import seaborn as sns

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# ## Load Dataset and Data Understanding
#
# Before analysis we explore:
#
# - Dataset structure
# - Column names
# - Dataset info
# - Remove duplicates
# - Statistical summary
# - Dataset shape
# - Dataset head
# - Dataset tail
# - Check unique
# - Check missing values
# - Check duplicates

# %%
# Import the dataset from Google Drive into a pandas DataFrame
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AlmaBetter/Final-Project-Files-Module-2/Capstone Project - 2 - FedEx Logistics Performance Analysis /FedEx Logistics Performance Analysis Dataset/SCMS_Delivery_History_Dataset.csv')

# Display concise summary of the DataFrame
# Includes column names, data types, and non-null values
df.info()

# Generate statistical summary of numerical columns
# Shows count, mean, std, min, max, and quartiles
df.describe()

# Get the shape of the dataset (rows, columns)
df.shape

# Display the first 5 rows of the dataset
df.head()

# Display the last 5 rows of the dataset
df.tail()

# Show all column names in the dataset
df.columns

# Check number of missing (null) values in each column
df.isnull().sum()

# Count number of unique values in each column
# dropna=False ensures NaN values are also counted
df.nunique(dropna=False)

# Count total duplicate rows in the dataset
df.duplicated().sum()

# Remove duplicate rows from the dataset
# inplace=True modifies the DataFrame directly
df.drop_duplicates(inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ## Data Cleaning
#
# Steps performed:
#
# - Remove duplicates
# - Convert date columns
# - Fill missing values
# - Standardize country names
#
# ## Feature Engineering
#
# - New variables are created to improve analysis.
#
# ### Created Columns
# - Lead Time Days
# - Delay Days
# - OnTime Delivery

# %%
# Convert date columns
date_columns = ['Scheduled Delivery Date', 'Delivered to Client Date']
df[date_columns] = df[date_columns].apply(pd.to_datetime, errors='coerce')

# Handle missing values
df['Shipment Mode'] = df['Shipment Mode'].fillna(df['Shipment Mode'].mode()[0])
df['Line Item Insurance (USD)'] = df['Line Item Insurance (USD)'].fillna(0)

# Clean country names
df['Country'] = df['Country'].str.strip().str.lower()

# Convert numeric columns
numeric_columns = ['Weight (Kilograms)', 'Freight Cost (USD)']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Create new features
df['Lead Time Days'] = (df['Delivered to Client Date'] - df['Scheduled Delivery Date']).dt.days
df['Delay Days'] = df['Lead Time Days']
df['OnTime'] = (df['Delivered to Client Date'] <= df['Scheduled Delivery Date']).astype(int)

# Convert 'Weight (Kilograms)' and 'Freight Cost (USD)' to numeric, coercing errors
#df['Weight (Kilograms)'] = pd.to_numeric(df['Weight (Kilograms)'], errors='coerce')
#df['Freight Cost (USD)'] = pd.to_numeric(df['Freight Cost (USD)'], errors='coerce')

# Display info again to confirm data types
df[['Weight (Kilograms)', 'Freight Cost (USD)']].info()
# Out:
# /tmp/ipykernel_2160/983160893.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_columns] = df[date_columns].apply(pd.to_datetime, errors='coerce')
# /tmp/ipykernel_2160/983160893.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_columns] = df[date_columns].apply(pd.to_datetime, errors='coerce')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Weight (Kilograms)  6372 non-null   float64
#  1   Freight Cost (USD)  6198 non-null   float64
# dtypes: float64(2)
# memory usage: 161.4 KB

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## Data Visulization
# Chart type:
#
# - Bar Chart
#
# - Pie Chart
#
# - Histogram
#
# - Scatter Plot
#
# - Boxplot
#
# - Line Chart
#
# - Heatmap
#
# - Pairplot

# %% [markdown]
# **Chart 1 — Shipment Volume by Country**

# %%
plt.figure(figsize=(15,5))
palette = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']
top_countries = df['Country'].value_counts().head(15)

sns.barplot(x=top_countries.index,
            y=top_countries.values,
            palette="viridis")

plt.title("Chart 1 - Top Countries by Shipment Volume")
plt.xlabel("Country")
plt.ylabel("Number of Shipments")


plt.show()
# Out:
# /tmp/ipykernel_2160/2409516382.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.index,

# %% [markdown]
# **Why did you pick this chart?**
#
# A bar chart is ideal for comparing shipment counts across multiple countries. It clearly highlights which countries receive the highest number of shipments.
#
# **Insights**
#
# Some countries handle significantly more shipments than others.
#
# A few countries dominate the shipment volume.
#
# This indicates strong demand or frequent supply requirements in those regions.
#
# **Business Impact**
#
# **Positive Impact**
#
# Helps FedEx prioritize logistics planning for high-volume countries.
#
# Warehouses and transportation resources can be allocated efficiently.
#
# **Negative Impact**
#
# Overdependence on a few countries could expose the company to geopolitical or economic risks.
#
# **Question**
# Which countries receive the most shipments?
#
# **Answer**
# Countries with the highest bars represent key logistics markets.

# %% [markdown]
# **Chart 2 — Distribution of Shipment Modes**

# %%
plt.figure(figsize=(7,7))

mode_counts = df['Shipment Mode'].value_counts()

plt.pie(mode_counts,
        labels=mode_counts.index,
        autopct='%1.1f%%',
        startangle=90)

plt.title("Chart 2 - Shipment Mode Distribution")

plt.show()

# %% [markdown]
# **Why did you pick this chart?**
#
# A pie chart helps understand the proportion of shipment modes used in the logistics network.
#
# **Insights**
#
# Air transport dominates shipment methods.
#
# Truck and Ocean are used less frequently.
#
# Charter shipments represent a very small portion.
#
# **Business Impact**
#
# **Positive Impact**
#
# Shows that the company prioritizes fast deliveries through air transport.
#
# **Negative Impact**
#
# Heavy reliance on air shipments may significantly increase operational costs.
#
#
# **Question**
# Which shipment mode is most frequently used?
#
# **Answer**
# The largest slice represents the most commonly used shipment mode.

# %% [markdown]
# **Chart 3 — Freight Cost Distribution**

# %%
plt.figure(figsize=(18,6))

sns.histplot(df['Freight Cost (USD)'],
             bins=30,
             kde=True,
             color='orange')

plt.title("Chart 3 - Freight Cost Distribution")
plt.xlabel("Freight Cost (USD)")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# **Why did you pick this chart?**
#
# A histogram helps understand the distribution of freight costs and identify common cost ranges.
#
# **Insights**
#
# Most shipments fall within a lower freight cost range.
#
# A few shipments have extremely high freight costs.
#
# **Business Impact**
#
# **Positive Impact**
#
# Helps identify normal shipping cost ranges for budgeting.
#
# **Negative Impact**
#
# Outliers with very high freight costs may reduce profit margins.
#
# **Question**
# Which shipment mode is most frequently used?
#
# **Answer**
# The largest slice in the chart represents the most commonly used shipment mode.

# %% [markdown]
# **Chart 4 — Shipment Weight Distribution**

# %%
plt.figure(figsize=(10,6))

# Scatter plot: x = Weight, y = index (to spread points)
plt.scatter(df['Weight (Kilograms)'], df.index, color='orange', alpha=0.6)

plt.title("Chart 4 - Shipment Weight Distribution (Scatter Plot)")
plt.xlabel("Weight (Kilograms)")
plt.ylabel("Shipment Index")
plt.show()

# %% [markdown]
# **Why did you pick this chart?**
#
# A scatter plot shows individual shipment weights as distinct points, making it easy to see the distribution, clusters, and outliers.
#
# **Insights**
#
# Some shipments are extremely heavy compared to the majority, clearly visible as outliers.
#
# **Business Impact**
#
# **Positive Impact**
#
# Helps logistics teams plan suitable transportation methods.
#
# **Negative Impact**
#
# Extremely heavy shipments may require specialized handling and increase costs.
#
# **Question**
# What does the scatter plot reveal about shipment weights?
#
# **Answer**
# Most shipments have lower weights, as shown by the denser cluster of points near the bottom of the weight scale, while fewer shipments are very heavy.

# %% [markdown]
# **Chart 5 — Vendor Shipment Contribution**

# %%
plt.figure(figsize=(12,6))

top_vendors = df['Vendor'].value_counts().head(5)

sns.barplot(x=top_vendors.index,
            y=top_vendors.values,
            palette="coolwarm",width=0.3)

plt.title("Chart 5 - Top Vendors by Shipment Count")
plt.ylabel("Number of Shipments")
plt.xlabel("Vendor")

plt.show()
# Out:
# /tmp/ipykernel_2160/2289855306.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vendors.index,

# %% [markdown]
# **Why did you pick this chart?**
#
# A bar chart effectively compares shipment counts across vendors.
#
# **Insights**
#
# A small number of vendors contribute the majority of shipments.
#
# Some vendors play a much larger role in the supply chain.
#
# **Business Impact**
#
# **Positive Impact**
#
# Strong partnerships with high-volume vendors improve efficiency.
#
# **Negative Impact**
#
# Dependency on limited vendors increases supply chain risk.
#
# **Question**
# Which vendors handle the most shipments?
#
# **Answer**
# The top 5 vendors are shown in the chart, with the tallest bars representing the vendors that handle the most shipments.

# %% [markdown]
# **Chart 6 — Average Lead Time by Shipment Mode**

# %%
plt.figure(figsize=(10,6))

sns.barplot(x='Shipment Mode',
            y='Delay Days',
            data=df,
            estimator=np.mean,palette="coolwarm")

plt.title("Chart 6 - Average Lead Time by Shipment Mode")
plt.ylabel("Average Delay (Days)")

plt.show()
# Out:
# /tmp/ipykernel_2160/844272086.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Shipment Mode',

# %% [markdown]
# **Why did you pick this chart?**
#
# A bar chart allows easy comparison of average delays across shipment modes.
#
# **Insights**
#
# Some transport modes experience higher delays.
#
# Air shipments tend to be faster compared to other modes.
#
# **Business Impact**
#
# **Positive Impact**
#
# Helps choose the most reliable shipment method.
#
# **Negative Impact**
#
# Slower shipment modes may impact customer satisfaction.
#
# **Question**
# Which shipment mode experiences the most delays?
#
# **Answer**
# The tallest bar indicates the shipment mode with the highest delay.

# %% [markdown]
# **Chart 7 — Average Lead Time by Year**

# %%
# Create 'Year' column
df['Year'] = df['Delivered to Client Date'].dt.year

# Calculate average Lead Time per year
yearly_lead_time = df.groupby('Year')['Lead Time Days'].mean().reset_index()

# Plot line chart
plt.figure(figsize=(10,6))
plt.plot(
    yearly_lead_time['Year'].astype(str),
    yearly_lead_time['Lead Time Days'],
    marker='o',
    linestyle='-',
    color='#ff7f0e',
    label='Avg Lead Time'
)
plt.title('Chart 7 - Average Lead Time Per Year')
plt.xlabel('Year')
plt.ylabel('Lead Time (Days)')
plt.grid(True, linestyle='--', alpha=0.9)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Why did you pick this chart?**
#
# A line chart is ideal for showing trends over time. It allows us to easily visualize increases or decreases in average lead time year by year.
#
# **Insights**
#
# Average lead time fluctuates over the years.
# Some years show longer delivery times, possibly due to operational delays, increased demand, or seasonal effects.
# Identifies trends in operational efficiency and delivery performance.
#
# **Business Impact**
#
# Positive Impact
# Helps FedEx identify years of improved efficiency and optimize resources for future periods.
#
# **Negative Impact**
# Years with longer lead times may indicate bottlenecks or strain on delivery capacity that need to be addressed.
#
# **Question**
# How does average lead time change over time?
#
# **Answer**
# The line trend shows fluctuations in delivery speed, highlighting periods of faster or slower operations.

# %% [markdown]
# **Chart 8 — Yearly Shipment Trend**

# %%
df['Shipment Date'] = pd.to_datetime(df['Scheduled Delivery Date'])

monthly_shipments = df.resample('Y', on='Shipment Date').size()

plt.figure(figsize=(12,6))

monthly_shipments.plot()

plt.title('Chart 8 - Year Shipment Trend')
plt.xlabel('Year')
plt.ylabel('Number of Shipments')
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_2160/3810920093.py:3: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   monthly_shipments = df.resample('Y', on='Shipment Date').size()

# %% [markdown]
# **Why did you pick this chart?**
#
# A line chart is ideal for showing trends over time. It allows us to easily visualize increases or decreases in shipment volumes year by year.
#
# **Insights**
#
# Shipment volumes fluctuate over the years.
#
# Some years show higher shipping activity, possibly due to seasonal demand or business expansion.
#
# Identifies long-term growth or decline in shipment trends.
#
# **Business Impact**
#
# **Positive Impact**
#
# Helps FedEx forecast demand and plan capacity for future years.
#
# **Negative Impact**
#
# Sudden spikes may strain operational resources if not anticipated.
#
# **Question**
# How do shipment volumes change over time?
#
# **Answer**
# The line trend shows fluctuations in shipment demand.

# %% [markdown]
# **Chart 9 — Top 10 Countries by Delayed Shipments**

# %%
# Map boolean to readable labels
df['Delayed'] = df['Lead Time Days'] > 0
df['DeliveryStatus'] = df['Delayed'].map({False:'Delayed', True:'On-Time'})

# Aggregate counts by Country and Delivery Status
agg_data = df.groupby(['Country', 'DeliveryStatus']).size().unstack(fill_value=0)

# Sort countries by number of delayed shipments and take top 10
top10_df = agg_data.sort_values('Delayed', ascending=False).head(10)

# Define colors: Delayed = red, On-Time = green
colors = ['#d62728', '#2ca02c']

# Plot side-by-side bars
top10_df.plot(
    kind='bar',
    figsize=(12,6),
    color=colors,
    width=0.6
)

plt.title('Chart 9 - Top 10 Countries by Delayed Shipments')
plt.xlabel('Country')
plt.ylabel('Number of Shipments')
plt.xticks(rotation=0)
plt.legend(title='Delivery Status')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Why did you pick this chart?**
#
# A grouped bar chart (side-by-side bars) is ideal for comparing categories across multiple groups. Here, it allows us to easily compare On-Time vs Delayed shipments for the top 10 countries.
#
# **Insights**
#
# Shipment performance varies significantly by country.
#
# Some countries have a higher proportion of on-time deliveries, while others experience more delays.
#
# Highlights operational strengths and areas needing improvement across regions.
#
# **Business Impact**
#
# **Positive Impact**
#
# Identifies countries with strong delivery performance, which can serve as benchmarks.
#
# Supports resource allocation and operational planning to improve delivery reliability.
#
# **Negative Impact**
#
# Countries with high delays may indicate logistical challenges, potential customer dissatisfaction, or risk to service reputation.
#
# **Question**
# Which countries have the most on-time vs delayed shipments?
#
# **Answer**
# The bar chart shows the comparison for the top 10 countries, highlighting where deliveries are mostly on-time versus delayed, helping prioritize operational focus.

# %% [markdown]
# **Chart 10 — Correlation Heatmap**

# %%
# Set figure size
plt.figure(figsize=(16,8))

numeric_df = df.select_dtypes(include='number')

# Compute correlation matrix
corr_matrix = numeric_df.corr()

# Plot heatmap
sns.heatmap(corr_matrix,
            annot=True,       # show correlation values
            fmt=".2f",        # 2 decimal places
            cmap="coolwarm",  # color map
            cbar=True)
plt.title("Chart 10 - Correlation Heatmap of Numeric Features")
plt.show()

# %% [markdown]
# **Why this chart was chosen:**
# A correlation heatmap helps quickly identify relationships between numeric variables. Strong correlations can indicate patterns that impact delivery performance.
#
# **Insights:**
#
# High correlation between distance and delivery delay may suggest longer routes tend to have more delays.
#
# Certain numeric variables may be weakly correlated, meaning they don’t directly impact delays.
#
# **Business Impact:**
#
# **Positive:**
# Helps identify key drivers of delivery delays for optimization.
#
# **Negative:**
# Ignoring strong correlations may result in inefficient shipment planning.
#
# **Question**
# Which numeric features are most strongly correlated?
#
# **Answer**
# The heatmap shows correlation values between numeric features, with darker colors and values closer to 1 or -1 indicating stronger positive or negative correlations, respectively.

# %% [markdown]
# **Chart 11 — Pairplot**

# %%
sns.pairplot(df, hue='Shipment Mode', diag_kind='kde')
plt.suptitle("Chart 11 -Pairplot of Numeric Features by Shipment Mode", y=1.02)
# Plot pairplot
plt.show()

# %% [markdown]
# **Why this chart was chosen:**
# A pairplot visualizes distributions and relationships between multiple numeric features, split by shipment mode. It’s useful for spotting patterns or clusters.
#
# **Insights:**
#
# Certain shipment modes may cluster in specific ranges of delay or distance.
#
# Outliers or extreme delays become more visible.
#
# **Business Impact:**
#
# **Positive:**
# Helps identify shipment modes prone to delays or special cases.
#
# **Negative:**
# Overlooking extreme outliers may mislead planning decisions.
#
# **Question**
# How do shipment modes relate to numeric features?
#
# **Answer**
# The pairplot shows relationships between numeric features, with points colored by shipment mode. Clusters or patterns in the scatterplots indicate how different shipment modes vary across features.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Overall, to achieve the business objectives, FedEx can leverage data analytics to optimize shipping routes and delivery methods, ensuring more efficient and timely operations. By diversifying shipping modes, the company can reduce dependency on a single method and increase operational flexibility. Implementing vendor performance evaluations enables the selection of reliable partners, improving service consistency. Monitoring freight costs allows for better control of high transportation expenses, while analyzing delivery delays helps detect and remove operational bottlenecks. Focusing on high-cost regions supports more effective regional logistics planning, and using real-time tracking and dashboards enhances decision-making while improving customer satisfaction. These strategies collectively strengthen FedEx’s operational efficiency and competitive position in the global logistics market.

# %% [markdown]
# **Table Content:**
#
# - Comments/ Remarks
# - Chart Detail
# - Insights
# - Business Impact(Positive/Negative)
# - Question
# - Answer

# %% [markdown]
# | Chart   Type                             | Comments / Remarks                                      | Why Chart is Used                                                          |
# | ------------------------------------- | ------------------------------------------------------------ | -------------------------------------------------------------------------- |
# | Shipment Volume by Country            | Bar chart chosen to compare shipment counts across countries | Bar charts are ideal for comparing quantities across categories            |
# | Distribution of Shipment Modes        | Pie chart chosen to show proportion of shipment modes        | Pie charts show percentages of a whole                                     |
# | Freight Cost Distribution             | Histogram chosen to understand cost distribution             | Histograms show distribution of numeric variables                          |
# | Shipment Weight Distribution          | Scatter plot shows individual shipment weights               | Scatter plots highlight spread, clusters, and outliers                     |
# | Vendor Shipment Contribution          | Bar chart to compare shipment counts across vendors          | Bar charts compare quantities across categories                            |
# | Average Lead Time by Shipment Mode    | Bar chart to compare delays across modes                     | Bar charts compare average numeric values across categories                |
# | Average Lead Time by Year             | Line chart to visualize trend over time                      | Line charts show trends and patterns over time                             |
# | Yearly Shipment Trend                 | Line chart to visualize shipment volume trends               | Line charts show changes over time                                         |
# | Top 10 Countries by Delayed Shipments | Grouped bar chart compares delayed vs on-time deliveries     | Grouped bars show multiple related categories across groups                |
# | Correlation Heatmap                   | Heatmap shows relationships between numeric variables        | Heatmaps highlight correlations                                            |
# | Pairplot                              | Pairplot visualizes relationships by shipment mode           | Pairplots show distributions and clusters across multiple numeric features |

# %% [markdown]
# | Chart Type                                                | Insights                                                            | Business Impact (Positive)                            | Business Impact (Negative)                            |
# | --------------------------------------------------------- | ------------------------------------------------------------------- | ----------------------------------------------------- | ----------------------------------------------------- |
# | Bar Chart (Shipment Volume by Country)                    | A few countries dominate shipment volume                            | Helps prioritize logistics planning                   | Overdependence on few countries                       |
# | Pie Chart (Distribution of Shipment Modes)                | Air transport dominates; Truck and Ocean less frequent              | Prioritizes fast deliveries                           | High operational cost due to air reliance             |
# | Histogram (Freight Cost Distribution)                     | Most shipments have lower freight cost; few outliers have high cost | Helps in budgeting and identifying normal cost ranges | High-cost outliers reduce profit margins              |
# | Scatter Plot (Shipment Weight Distribution)               | Some shipments are extremely heavy                                  | Helps plan transportation methods                     | Heavy shipments require special handling              |
# | Bar Chart (Vendor Shipment Contribution)                  | A few vendors contribute majority of shipments                      | Strong partnerships improve efficiency                | Few vendors increases supply chain risk |
# | Bar Chart (Average Lead Time by Shipment Mode)            | Some shipment modes have higher delays; Air is fastest              | Helps choose reliable shipment mode                   | Slow modes impact customer satisfaction               |
# | Line Chart (Average Lead Time by Year)                    | Lead time fluctuates yearly                                         | Identify efficiency improvements                      |Long Lead times indicate operational bottlenecks    |
# | Line Chart (Yearly Shipment Trend)                        | Shipment volumes fluctuate; some years higher                       | Forecast demand and plan capacity                     | Sudden spikes may strain resources                    |
# | Grouped Bar Chart (Top 10 Countries by Delayed Shipments) | Performance varies; some countries have more delays                 | Identify strong delivery countries                    | Countries with delays may cause dissatisfaction       |
# | Heatmap (Correlation Heatmap)                             | Distance and delay are strongly correlated                          | Identify drivers of delays                            | Ignoring correlations may cause inefficiency          |
# | Pairplot (Pairplot by Shipment Mode)                      | Certain modes cluster in specific delay or cost ranges              | Identify modes prone to delays                        | Outliers can mislead planning                         |

# %% [markdown]
# | Chart Type                                                | Question                                                    | Answer                                                                       |
# | --------------------------------------------------------- | ----------------------------------------------------------- | ---------------------------------------------------------------------------- |
# | Bar Chart (Shipment Volume by Country)                    | Which countries receive the most shipments?                 | Countries with the highest bars represent key logistics markets              |
# | Pie Chart (Distribution of Shipment Modes)                | Which shipment mode is most frequently used?                | The largest slice represents the most commonly used shipment mode            |
# | Histogram (Freight Cost Distribution)                     | What does the freight cost distribution reveal?             | Most shipments have lower costs, few have very high costs                    |
# | Scatter Plot (Shipment Weight Distribution)               | What does the scatter plot reveal about shipment weights?   | Most shipments have lower weights; very heavy shipments are outliers         |
# | Bar Chart (Vendor Shipment Contribution)                  | Which vendors handle the most shipments?                    | Top 5 vendors are tallest bars representing highest shipments                |
# | Bar Chart (Average Lead Time by Shipment Mode)            | Which shipment mode experiences the most delays?            | The tallest bar indicates the mode with highest delay                        |
# | Line Chart (Average Lead Time by Year)                    | How does average lead time change over time?                | Line trend shows fluctuations, highlighting faster or slower periods         |
# | Line Chart (Yearly Shipment Trend)                        | How do shipment volumes change over time?                   | Line trend shows shipment demand fluctuations                                |
# | Grouped Bar Chart (Top 10 Countries by Delayed Shipments) | Which countries have the most on-time vs delayed shipments? | Bar chart shows top 10 countries highlighting on-time vs delayed             |
# | Heatmap (Correlation Heatmap)                             | Which numeric features are most strongly correlated?        | Darker colors and values closer to 1 or -1 indicate strong correlation       |
# | Pairplot (Pairplot by Shipment Mode)                      | How do shipment modes relate to numeric features?           | Points colored by shipment mode reveal clusters and patterns across features |

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Final Verdict**
#
# This analysis revealed important operational patterns in the logistics network:
#
# Key Insights:
#
# -A small number of countries account for the majority of shipments, indicating concentrated demand.
#
# -Shipment mode significantly influences delivery speed and the likelihood of delays.
#
# -Freight cost increases as shipment weight increases, showing a strong relationship between weight and cost.
#
# -Delivery delays vary depending on the shipment mode used.
#
# -Shipment volumes fluctuate over time, reflecting changing logistics demand trends.
#
# -Air transport dominates shipments but increases costs.
#
# -Shipment weight strongly influences freight costs.
#
# -Longer distances are linked to higher delivery delays and costs.
#
# -Express shipping reduces delivery time but raises expenses.
#
# -Outliers in delivery times indicate shipments needing special attention.
#
# -Clusters in shipment modes reveal distinct patterns in cost, distance, and transit time.
#
# -A few vendors and countries account for most shipments.
#
# -Some shipment modes experience higher delays.
#
# Using these insights, FedEx can optimize logistics planning, reduce costs, and enhance delivery reliability across its network & help improve logistics strategy and operational efficiency.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
